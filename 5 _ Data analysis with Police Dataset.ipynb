# %% [markdown]
# # Police Data set

# %%
import pandas as pd 
import numpy as np 
data = pd.read_csv("./Downloads/police_file.csv")

# %%
data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# # 1) Remove the Column that Only Contains null value

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
data.drop(columns="country_name", inplace=True)

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ## country name removed

# %% [markdown]
# # 2)  For Speeding , Where men or women stopped nore often ?

# %%
data[data.violation == "Speeding"].driver_gender.value_counts()
# Out:
# driver_gender
# M    25517
# F    11686
# Name: count, dtype: int64

# %% [markdown]
# # 3 ) Does gender Affect who gets searched during a stop ?

# %%
data.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
data.search_conducted.value_counts()
# Out:
# search_conducted
# False    63056
# True      2479
# Name: count, dtype: int64

# %% [markdown]
# # 4 )  whats is the mean stop duration

# %%
# here the stop_duration coulmn is object type   
data.stop_duration.value_counts()
# Out:
# stop_duration
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: count, dtype: int64

# %%
data["stop_duration"] = data["stop_duration"].map({"0-15 Min" : 7.5 , "16-30 Min" : 24 ,"30+ Min" : 45 })

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
data["stop_duration"].mean()
# Out:
# 12.187420698181345

# %% [markdown]
# ###  Question ( groupby , Describe)
# ---
# # Compare the age distribbutions for ach violation

# %%
data.sample()
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 32735  2/21/2009     15:48             M          1989.0        20.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# 32735       White      Speeding  Speeding             False         NaN
#
#       stop_outcome is_arrested  stop_duration  drugs_related_stop
# 32735     Citation       False           24.0               False

# %%
data.groupby("violation").driver_age_raw.describe()
# Out:
#                        count         mean         std     min     25%     50%  \
# violation
# Equipment             6515.0  1975.935380   65.818854     0.0  1971.0  1981.0
# Moving violation     11926.0  1965.462770  120.359733     0.0  1963.0  1974.0
# Other                 3583.0  1912.442088  329.302162     0.0  1959.0  1968.0
# Registration/plates   2243.0  1973.686135   73.103745     0.0  1969.0  1979.0
# Seat belt                3.0  1981.666667   10.214369  1970.0  1978.0  1986.0
# Speeding             37204.0  1972.189711   86.672468     0.0  1966.0  1979.0
#
#                         75%     max
# violation
# Equipment            1987.0  2005.0
# Moving violation     1984.0  2006.0
# Other                1979.0  2011.0
# Registration/plates  1985.0  1996.0
# Seat belt            1987.5  1989.0
# Speeding             1985.0  8801.0
